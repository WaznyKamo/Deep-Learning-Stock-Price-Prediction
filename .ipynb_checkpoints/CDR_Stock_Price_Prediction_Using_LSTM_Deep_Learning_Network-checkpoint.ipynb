# %% [markdown]
# Prediction of stock prices on example of CD PROJEKT RED
#
# Daily data used in the notebook comes from: https://stooq.pl/q/d/?s=cdr
# In order to load data one should download a file, load it into Google Drive and change the mounting point path
#
# The program will ask for logging in into your google account in order to mount data from the Drive to Colab.

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2.4.0
# 2.4.3

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3228670805679349266
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8855182400
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10059246734624178838
# physical_device_desc: "device: 0, name: GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import pandas as pd
import numpy as np

daily_data = pd.read_csv("WiG20 data/cdr_d.csv")

daily_data.tail()
# Out:
#             Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie    Wolumen
# 6592  2021-02-24     258.2      262.3      256.0       258.2   341058.0
# 6593  2021-02-25     255.0      256.0      249.1       251.6   767659.0
# 6594  2021-02-26     249.6      249.9      234.2       236.6  1478281.0
# 6595  2021-03-01     237.4      241.0      225.2       240.3  1089101.0
# 6596  2021-03-02     240.9      245.9      236.0       241.3   674141.0

# %%
daily_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6597 entries, 0 to 6596
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        6597 non-null   object
#  1   Otwarcie    6597 non-null   float64
#  2   Najwyzszy   6597 non-null   float64
#  3   Najnizszy   6597 non-null   float64
#  4   Zamkniecie  6597 non-null   float64
#  5   Wolumen     6596 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 309.4+ KB

# %%
null_columns = daily_data.columns[daily_data.isnull().any()]
daily_data.isnull().sum()
# Out:
# Data          0
# Otwarcie      0
# Najwyzszy     0
# Najnizszy     0
# Zamkniecie    0
# Wolumen       1
# dtype: int64

# %%
## Droping last 100 rows to check if the NN would perform better
daily_data = daily_data.iloc[:-100]

# %%
daily_data['Data'] = pd.to_datetime(daily_data.Data)

# %%
print(daily_data[daily_data["Wolumen"].isnull()]) # row with a null value
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 79 1994-12-08    5.1204     5.1204     5.1204      5.1204      NaN

# %% [markdown]
# In given dataset on 1994-12-08 the Wolumen value is null. According to https://www.biznesradar.pl/notowania-historyczne/CD-PROJEKT,130 it should be 0, so the value has to be overwritten.

# %%
daily_data.fillna(0, inplace=True)
print(daily_data[daily_data["Wolumen"].isnull()])
# Out:
# Empty DataFrame
# Columns: [Data, Otwarcie, Najwyzszy, Najnizszy, Zamkniecie, Wolumen]
# Index: []

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=daily_data['Data'],
                                     open=daily_data['Otwarcie'],
                                     high=daily_data['Najwyzszy'],
                                     low=daily_data['Najnizszy'],
                                     close=daily_data['Zamkniecie'])])

fig.update_layout(title='Stock price of CD Projekt',
                  yaxis_title='Price',
                  xaxis_title='Date')
fig.show()

# slider below the plot can be used for narrowing the dates
# Out:
# <div>                            <div id="5badd563-2e37-4ede-bc32-95a7cebec179" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5badd563-2e37-4ede-bc32-95a7cebec179")) {                    Plotly.newPlot(                        "5badd563-2e37-4ede-bc32-95a7cebec179",                        [{"close": [8.2789, 9.0931, 9.995, 9.0931, 10.732, 10.123, 9.917, 10.536, 11.065, 9.956, 10.33, 9.505, 9.299, 8.3575, 9.0538, 9.0146, 8.4849, 8.2789, 7.8669, 7.0724, 6.3759, 6.9841, 7.661, 6.9056, 7.0233, 6.886, 6.8664, 6.1895, 5.6304, 5.856, 5.6991, 5.2872, 5.2872, 5.5912, 6.1503, 6.2092, 6.8272, 6.7193, 6.8468, 6.7193, 6.4152, 6.4152, 5.7776, 6.3269, 6.6212, 6.8272, 6.7193, 6.6016, 6.2681, 5.7972, 5.8756, 5.9051, 5.5912, 5.4735, 6.0228, 5.9639, 5.9443, 5.9051, 5.9051, 5.9247, 5.9247, 5.9051, 5.4735, 5.4735, 5.3656, 5.6795, 5.1008, 4.6103, 4.6691, 4.6495, 4.6691, 5.1008, 5.6108, 6.0817, 6.0424, 5.4245, 5.6991, 5.5716, 5.6991, 5.1204, 4.6691, 5.0615, 4.8751, 4.7771, 4.8751, 5.346, 5.2676, 5.2086, 5.1204, 5.2676, 5.2676, 5.2282, 5.0615, 5.1008, 5.6108, 5.3264, 5.4735, 5.5912, 5.3068, 5.4245, 5.4245, 5.4539, 5.5128, 5.5912, 5.5324, 5.4735, 5.3852, 5.4735, 5.4539, 5.2676, 4.983, 4.9537, 4.9537, 5.0026, 4.9537, 4.9537, 5.0615, 5.0615, 4.9537, 5.2086, 5.7384, 5.6304, 5.2676, 5.2676, 5.1596, 5.3656, 5.2282, 5.346, 5.2872, 5.1008, 4.8359, 4.8947, 4.983, 5.4735, 4.9341, 4.9537, 5.0223, 5.1596, 5.2282, 5.2086, 5.1596, 5.2282, 5.2479, 5.1793, 5.14, 5.0615, 5.1596, 5.0615, 5.0812, 5.0026, 5.0223, 5.0026, 4.9537, 4.983, 5.0026, 4.9341, 4.8359, 4.8555, 4.9537, 5.0615, 5.1596, 5.1596, 5.2282, 5.3656, 5.9247, 5.9639, 5.9639, 5.6991, 5.8364, 6.3073, 6.9253, 6.8272, 6.6212, 6.9449, 6.8272, 6.2681, 6.3759, 6.4152, 6.6408, 6.8664, 7.2294, 7.965, 8.691, 8.2789, 8.8086, 7.9258, 7.9258, 7.6414, 7.5825, 7.0724, 6.3759, 6.9841, 7.661, 7.5236, 7.5236, 7.1901, 6.4937, 6.4152, 6.5133, 6.7193, 7.0233, 7.2294, 7.0233, 6.8272, 6.4348, 6.6212, 6.8272, 6.4152, 6.4152, 6.6212, 6.6212, 6.5133, 6.6604, 7.0037, 7.0233, 6.4545, 6.6212, 6.6212, 6.7193, 6.4741, 6.2092, 6.2092, 6.2681, 5.6501, 5.758, 5.5912, 5.7187, 5.7187, 5.8756, 5.856, 5.7776, 5.6108, 5.4735, 5.1596, 5.2872, 5.2872, 5.8168, 6.3956, 6.0228, 6.0032, 6.1013, 5.9639, 5.856, 5.9051, 5.6304, 5.5716, 5.8364, 5.7972, 5.9836, 5.9836, 5.9836, 5.758, 6.0032, 6.0032, 5.9443, 5.9836, 6.2092, 6.3073, 6.3073, 6.3073, 6.4152, 6.7193, 6.886, 6.9253, 7.0233, 7.3176, 7.661, 7.6217, 7.4354, 7.6806, 7.6021, 7.2294, 6.5133, 6.4741, 6.5721, 6.4937, 6.5329, 6.6212, 6.8272, 6.1503, 6.5329, 6.6212, 6.5721, 6.2092, 6.1013, 6.3073, 6.0228, 5.9639, 5.9443, 5.9443, 5.9051, 5.856, 6.0032, 5.9639, 5.7972, 5.4735, 5.4735, 5.3656, 5.3656, 5.4735, 5.6795, 5.6795, 5.5128, 5.6795, 5.7972, 5.9247, 5.9051, 5.9639, 5.7776, 5.5128, 5.4932, 5.4932, 5.5324, 5.4539, 5.4735, 5.1596, 5.3264, 5.5324, 5.5324, 5.3852, 5.4735, 5.3852, 5.4539, 5.6501, 5.7972, 5.7972, 6.0032, 5.9051, 5.9051, 5.7776, 5.9639, 5.856, 5.7972, 5.7972, 5.7384, 5.758, 5.6991, 5.1204, 5.2086, 5.2676, 5.3656, 5.3656, 5.1204, 5.2479, 5.2872, 5.346, 5.5716, 5.6108, 5.7972, 5.7776, 5.9051, 5.7972, 5.6108, 5.7972, 5.9836, 5.7972, 5.6108, 5.7972, 5.6304, 5.7972, 5.9051, 6.0032, 6.3956, 6.3073, 6.4152, 6.2092, 6.2092, 5.9639, 5.9639, 5.7972, 5.7972, 5.9639, 6.2877, 5.7384, 5.856, 5.6795, 5.6108, 5.6108, 5.5912, 5.4735, 5.5912, 5.4735, 5.5912, 5.7384, 5.758, 6.0032, 6.1013, 6.2485, 6.2092, 6.1013, 6.1013, 6.0817, 6.0424, 5.9639, 5.9639, 5.9836, 5.9836, 6.1699, 6.3073, 6.1013, 6.1013, 5.856, 5.6795, 5.7776, 5.8756, 5.7776, 5.856, 5.8756, 5.758, 5.7776, 5.7972, 5.9051, 6.0032, 6.0817, 6.0032, 6.0032, 5.9051, 5.9639, 6.0228, 6.0621, 6.0032, 6.1013, 6.3073, 6.6212, 7.0233, 6.9253, 7.0233, 6.9841, 7.4354, 7.9062, 7.9062, 7.8669, 7.6414, 7.6021, 7.4158, 7.2294, 7.17 ...

# %% [markdown]
# # Preparation of data for prediction

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(data):
    list_of_features = []
    list_of_outputs = []
    for column in data.columns:
        list_of_features.append(data[column])
        if column in ['Otwarcie', 'Zamkniecie', 'Najwyzszy', 'Najnizszy', 'Wolumen']:
            list_of_outputs.append(data[column])
        
    dataset = np.transpose(list_of_features)
    output_dataset = np.transpose(list_of_outputs)
    X_scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = X_scaler.fit_transform(dataset)
    Y_scaler = MinMaxScaler(feature_range=(0,1))
    Y_scaler.fit_transform(output_dataset)

    return scaled_data, X_scaler, Y_scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# expected input data shape [number of training examples, number of data in single example (days considered for prediction), number of features]
def preprocess_scaled_data(data):
    list_of_features = []
    for column in data.columns:
        list_of_features.append(data[column])

    dataset = np.transpose(list_of_features)

    scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = scaler.fit_transform(dataset)

    return scaled_data, scaler

# %%
dataset, X_scaler, Y_scaler = scale_data(daily_data.drop(columns=['Data']))
print('dataset shape: ' + str(dataset.shape))
validation_set_size = 60

# using data from last n (validation_set_size) days for validation, rest for training
training_data = dataset[:-validation_set_size,:]

x_train = []
y_train = []
x_valid = []
y_valid = []

# predicting prices from data from last 60 days
for i in range(60, training_data.shape[0]):
    x_train.append(training_data[i-60:i, :])
    y_train.append(training_data[i,:])

x_train, y_train = np.array(x_train), np.array(y_train)

print('x_train shape: ' + str(x_train.shape))
print('y_train shape: ' + str(y_train.shape))

for i in range(dataset.shape[0] - validation_set_size, dataset.shape[0]):
    x_valid.append(dataset[i-60:i, :])
    y_valid.append(dataset[i,:])

x_valid, y_valid = np.array(x_valid), np.array(y_valid)

print('x_valid shape: ' + str(x_valid.shape))
print('y_valid shape: ' + str(y_valid.shape))
# Out:
# dataset shape: (6497, 5)
# x_train shape: (6377, 60, 5)
# y_train shape: (6377, 5)
# x_valid shape: (60, 60, 5)
# y_valid shape: (60, 5)

# %% [markdown]
# ## Defining the LSTM Model

# %%
import numpy as np
import tensorflow as tf
from keras.models import Model
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Lambda, Dropout, Conv1D
import matplotlib.pyplot as plt

# %%
model = Sequential()
model.add(LSTM(64, input_shape=[x_train.shape[1], x_train.shape[2]])) #), return_sequences=True))
#model.add(LSTM(64))
#model.add(Dropout(0.3))
model.add(Dense(100))
model.add(Dense(y_train.shape[1]))

model.summary()

model.compile(loss='mae', optimizer='adam')

history = model.fit(x_train, y_train, epochs=15, validation_data=(x_valid, y_valid))

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 64)                17920
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               6500
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 24,925
# Trainable params: 24,925
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 200/200 [==============================] - 2s 5ms/step - loss: 0.0148 - val_loss: 0.0282
# Epoch 2/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0060 - val_loss: 0.0265
# Epoch 3/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0059 - val_loss: 0.0180
# Epoch 4/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0053 - val_loss: 0.0224
# Epoch 5/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0054 - val_loss: 0.0182
# Epoch 6/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0152
# Epoch 7/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0169
# Epoch 8/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0051 - val_loss: 0.0194
# Epoch 9/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0268
# Epoch 10/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0156
# Epoch 11/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0048 - val_loss: 0.0168
# Epoch 12/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0049 - val_loss: 0.0139
# Epoch 13/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0120
# Epoch 14/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0160
# Epoch 15/15
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0049 - val_loss: 0.0136

# %%
# Evaluation of the results is made on closing prices - it gives the most information about the usefullness of the model.  Made on the last 30 days of the stock data

predictions = model.predict(x_valid)
predictions = Y_scaler.inverse_transform(predictions)

mae = np.mean(np.abs((predictions[:,1] - Y_scaler.inverse_transform(y_valid)[:,1])))
naive_forcast_difference = [abs(Y_scaler.inverse_transform(y_valid)[i + 1,1] - Y_scaler.inverse_transform(y_valid)[i,1]) for i in range(y_valid.shape[0] - 1)]
naive_forcast_mae = sum(naive_forcast_difference) / len(naive_forcast_difference)

mape = np.mean((np.abs((predictions[:,1] - Y_scaler.inverse_transform(y_valid)[:,1]))/Y_scaler.inverse_transform(y_valid)[:,1])*100)
naive_forcast_mape = (naive_forcast_mae/Y_scaler.inverse_transform(y_valid)[:,1].mean()) * 100


print('Prediction mean absolute error: ' + str(mae))
print('Naive forcast mean absolute error: ' + str(naive_forcast_mae))

print('Prediction mean absolute percentage error: ' + str(mape))
print('Naive forcast mean absolute percentage error: ' + str(naive_forcast_mape))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002306CF11EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Prediction mean absolute error: 5.594506937662763
# Naive forcast mean absolute error: 6.423728813559322
# Prediction mean absolute percentage error: 1.3478416591152702
# Naive forcast mean absolute percentage error: 1.5405364318574801

# %%
# Comparision of the closing stock prices
inversed_dataset = Y_scaler.inverse_transform(dataset)
print('Closing prices: Predicted/Real/Difference/Percentage difference')
closing_prices = daily_data['Zamkniecie']

for i in range(predictions.shape[0]):
  difference = round(predictions[i, 1] - daily_data['Zamkniecie'].iloc[-validation_set_size + i], 1)
  diff_percent = (difference/daily_data['Zamkniecie'].iloc[-validation_set_size + i]) * 100

  print(str(round(predictions[i, 1], 1)) + ' / ' + str(daily_data['Zamkniecie'].iloc[-validation_set_size + i]) + ' / ' + str(difference) + ' / ' + str(round(diff_percent,2)) + '%')
# Out:
# Closing prices: Predicted/Real/Difference/Percentage difference
# 379.2 / 353.9 / 25.3 / 7.15%
# 362.2 / 365.0 / -2.8 / -0.77%
# 377.1 / 368.3 / 8.8 / 2.39%
# 374.5 / 371.0 / 3.5 / 0.94%
# 377.2 / 393.1 / -15.9 / -4.04%
# 397.5 / 381.0 / 16.5 / 4.33%
# 389.4 / 383.0 / 6.4 / 1.67%
# 387.8 / 387.5 / 0.3 / 0.08%
# 393.8 / 388.0 / 5.8 / 1.49%
# 392.1 / 399.2 / -7.1 / -1.78%
# 403.4 / 395.2 / 8.2 / 2.07%
# 399.6 / 401.0 / -1.4 / -0.35%
# 406.2 / 398.5 / 7.7 / 1.93%
# 407.3 / 402.0 / 5.3 / 1.32%
# 407.7 / 417.0 / -9.3 / -2.23%
# 421.5 / 417.5 / 4.0 / 0.96%
# 424.2 / 410.0 / 14.2 / 3.46%
# 416.1 / 412.5 / 3.6 / 0.87%
# 418.8 / 427.0 / -8.2 / -1.92%
# 432.3 / 425.4 / 6.9 / 1.62%
# 433.0 / 416.6 / 16.4 / 3.94%
# 422.2 / 418.0 / 4.2 / 1.0%
# 422.9 / 410.7 / 12.2 / 2.97%
# 418.7 / 410.7 / 8.0 / 1.95%
# 417.6 / 408.0 / 9.6 / 2.35%
# 416.0 / 406.3 / 9.7 / 2.39%
# 411.8 / 415.0 / -3.2 / -0.77%
# 420.1 / 408.6 / 11.5 / 2.81%
# 414.0 / 409.2 / 4.8 / 1.17%
# 417.2 / 414.6 / 2.6 / 0.63%
# 422.0 / 408.0 / 14.0 / 3.43%
# 414.9 / 437.0 / -22.1 / -5.06%
# 440.3 / 460.8 / -20.5 / -4.45%
# 463.9 / 446.0 / 17.9 / 4.01%
# 450.3 / 438.5 / 11.8 / 2.69%
# 444.0 / 440.7 / 3.3 / 0.75%
# 447.8 / 439.9 / 7.9 / 1.8%
# 448.1 / 430.6 / 17.5 / 4.06%
# 438.4 / 428.0 / 10.4 / 2.43%
# 432.2 / 436.6 / -4.4 / -1.01%
# 442.6 / 433.4 / 9.2 / 2.12%
# 439.4 / 432.0 / 7.4 / 1.71%
# 437.6 / 429.0 / 8.6 / 2.0%
# 436.3 / 430.2 / 6.1 / 1.42%
# 437.0 / 417.3 / 19.7 / 4.72%
# 426.4 / 403.0 / 23.4 / 5.81%
# 410.8 / 405.3 / 5.5 / 1.36%
# 415.0 / 404.0 / 11.0 / 2.72%
# 410.1 / 402.1 / 8.0 / 1.99%
# 412.7 / 385.3 / 27.4 / 7.11%
# 396.2 / 400.9 / -4.7 / -1.17%
# 410.2 / 407.0 / 3.2 / 0.79%
# 414.4 / 402.6 / 11.8 / 2.93%
# 409.5 / 410.0 / -0.5 / -0.12%
# 415.0 / 429.6 / -14.6 / -3.4%
# 434.9 / 431.4 / 3.5 / 0.81%
# 436.2 / 418.4 / 17.8 / 4.25%
# 425.2 / 382.6 / 42.6 / 11.13%
# 390.5 / 397.2 / -6.7 / -1.69%
# 405.6 / 398.7 / 6.9 / 1.73%

# %%
closing_prices = Y_scaler.inverse_transform(dataset)[-validation_set_size:,1]

predicted_closing_prices = np.round(predictions[:, 1], 1)

plt.figure(figsize=(25,10))
plt.title('Comparision of real and predicted closing prices of CD Projekt', fontsize=24)
plt.xlabel('Date', fontsize=25)
plt.ylabel('Closing price (zł)', fontsize=18)
plt.plot(closing_prices)
plt.plot(predicted_closing_prices)
plt.legend(['Real price',  'Predicted price'], loc='lower right')
plt.show()

# %% [markdown]
# # Conclusion:
#
# A single company data is not enough for getting useful predictions from neural network, although, considering small amount of training data, the results are pretty accurate (very close to naive prediction).
#
# Training the neural network on more data (using more companies' data) and using more input features like indicators of technical or fundamental analysis and maybe some external factors might make predictions much better and useful in real world applications.

# %% [markdown]
# # Adding technical indicators to the neural network

# %%
daily_data.head()
# Out:
#         Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# 0 1994-08-02    8.2789     8.2789     8.2789      8.2789  347109.0
# 1 1994-08-03    9.0931     9.0931     9.0931      9.0931  325196.0
# 2 1994-08-04    9.9950     9.9950     9.9950      9.9950  355499.0
# 3 1994-08-08    9.0931     9.0931     9.0931      9.0931  263619.0
# 4 1994-08-09   10.7320    10.7320    10.7320     10.7320  135441.0

# %% [markdown]
# **Moving averages on closing prices for periods of 10, 30 and 60 days**

# %%
daily_data['MovingAverage10'] = daily_data['Zamkniecie'].rolling(10).mean()
daily_data['MovingAverage30'] = daily_data['Zamkniecie'].rolling(30).mean()
daily_data['MovingAverage60'] = daily_data['Zamkniecie'].rolling(60).mean()

datapoints_to_show = 300

plt.figure(figsize=(25,10))
plt.plot(daily_data['Data'].tail(datapoints_to_show), daily_data[['Zamkniecie', 'MovingAverage10', 'MovingAverage30', 'MovingAverage60']].tail(datapoints_to_show))
plt.title('Moving averages of the last ' + str(datapoints_to_show) + ' datapoints', fontsize=24)
plt.xlabel('Date', fontsize=25)
plt.ylabel('Price (zł)', fontsize=18)
plt.legend(['Closing',  '10-day moving average',  '30-day moving average',  '60-day moving average'], loc='lower right')

# %% [markdown]
# **RSI**

# %%
period = 10
increase_diffrence, decrease_diffrence = daily_data['Zamkniecie'].diff(), daily_data['Zamkniecie'].diff()

increase_diffrence[increase_diffrence < 0] = 0
decrease_diffrence[decrease_diffrence > 0] = 0
# calculating EWMA (exponential moving average)
roll_increase = increase_diffrence.ewm(span = period).mean()
roll_decrease = decrease_diffrence.abs().ewm(span = period).mean()

RS = roll_increase / roll_decrease

RSI = 100 - (100 / (1 + RS))

daily_data['RSI'] = RSI

# %%
datapoints_to_show = 1000
plt.figure(figsize=(25,10))
plt.plot(daily_data['Data'].tail(datapoints_to_show), daily_data['RSI'].tail(datapoints_to_show))
plt.title('RSI of the last ' + str(datapoints_to_show) + ' datapoints', fontsize=24)
plt.xlabel('Date', fontsize=25)
plt.ylabel('RSI', fontsize=18)
# Out:
# Text(0, 0.5, 'RSI')

# %% [markdown]
# **Rate of Change (ROC)**

# %%
daily_data['ROC'] = daily_data['Zamkniecie'].pct_change()

# %% [markdown]
# **Stochastic oscillator**
#
# K = (C - L14)/(H14 - L14)
#
# Where
# * C - closing price,
# * L14 - lowest closing price from previous 14 sessions,
# * H14 - highest closing price from previous closing sessions
#
# D - moving average of the stochastic oscillator K

# %%
window_size = 14
D_window_size = 4
L14, H14 = daily_data['Zamkniecie'].rolling(window_size).min(), daily_data['Zamkniecie'].rolling(window_size).max()

daily_data['K'] = (daily_data['Zamkniecie'] - L14)/(H14 - L14)
daily_data['D'] = daily_data['K'].rolling(D_window_size).mean()

# %% [markdown]
# **MACD, MACD Signal Line, their difference and Price Oscillator**

# %%
# 12 period moving average
EMA_26 = daily_data['Zamkniecie'].ewm(26).mean()
EMA_12 = daily_data['Zamkniecie'].ewm(12).mean()


daily_data['MACD'] = EMA_12 - EMA_26

daily_data['MACD_Signal'] = daily_data['MACD'].ewm(9).mean()

daily_data['MACD_Histogram'] = daily_data['MACD'] - daily_data['MACD_Signal']

daily_data['PPO'] =(EMA_12 - EMA_26)/EMA_26

# %%
datapoints_to_show = 200 

fig, (ax1, ax2) = plt.subplots(2)
fig.set_size_inches(25,10)
#plt.figure(figsize=(25,10))
fig.suptitle('MACD', fontsize=24)

ax1.plot(daily_data['Data'].tail(datapoints_to_show), daily_data['Zamkniecie'].tail(datapoints_to_show))
ax2.plot(daily_data['Data'].tail(datapoints_to_show), daily_data[['MACD', 'MACD_Signal']].tail(datapoints_to_show))
ax2.bar(daily_data['Data'].tail(datapoints_to_show), daily_data['MACD_Histogram'].tail(datapoints_to_show))

ax2.legend(['MACD Line', 'Signal Line'])

# %% [markdown]
# **Triple Exponential Moving Average TEMA**

# %%
window_size = 10

SEMA = daily_data['Zamkniecie'].ewm(window_size).mean()
DEMA = SEMA.ewm(window_size).mean()
daily_data['TEMA'] = DEMA.ewm(window_size).mean()

# %% [markdown]
# **Commodity Channel Index CCI**

# %%
window_size = 20
typical_price = (daily_data['Najwyzszy'] + daily_data['Najnizszy'] + daily_data['Zamkniecie']) / 3
MA = typical_price.rolling(window_size).mean()
mean_deviation = (MA - typical_price).abs().rolling(window_size).mean()

daily_data['CCI'] = (typical_price - MA) / (0.15 * mean_deviation)

# %% [markdown]
# **Williams Percent Range**

# %%
window_size = 14
daily_data['Percent_Range'] = (daily_data['Najwyzszy'].rolling(window_size).max() - daily_data['Zamkniecie']) / (daily_data['Najwyzszy'].rolling(window_size).max() - daily_data['Najnizszy'].rolling(window_size).min())

# %%
daily_data.head(60)
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen  \
# 0  1994-08-02    8.2789     8.2789     8.2789      8.2789  347109.0
# 1  1994-08-03    9.0931     9.0931     9.0931      9.0931  325196.0
# 2  1994-08-04    9.9950     9.9950     9.9950      9.9950  355499.0
# 3  1994-08-08    9.0931     9.0931     9.0931      9.0931  263619.0
# 4  1994-08-09   10.7320    10.7320    10.7320     10.7320  135441.0
# 5  1994-08-10   10.1230    10.1230    10.1230     10.1230  156263.0
# 6  1994-08-11    9.9170     9.9170     9.9170      9.9170  127846.0
# 7  1994-08-16   10.5360    10.5360    10.5360     10.5360   81439.0
# 8  1994-08-17   11.0650    11.0650    11.0650     11.0650   82459.0
# 9  1994-08-18    9.9560     9.9560     9.9560      9.9560   54547.0
# 10 1994-08-22   10.3300    10.3300    10.3300     10.3300  105020.0
# 11 1994-08-23    9.5050     9.5050     9.5050      9.5050   68436.0
# 12 1994-08-24    9.2990     9.2990     9.2990      9.2990   75990.0
# 13 1994-08-25    8.3575     8.3575     8.3575      8.3575   64062.0
# 14 1994-08-29    9.0538     9.0538     9.0538      9.0538   88751.0
# 15 1994-08-30    9.0146     9.0146     9.0146      9.0146   57584.0
# 16 1994-08-31    8.4849     8.4849     8.4849      8.4849   46757.0
# 17 1994-09-01    8.2789     8.2789     8.2789      8.2789   68146.0
# 18 1994-09-05    7.8669     7.8669     7.8669      7.8669   43109.0
# 19 1994-09-06    7.0724     7.0724     7.0724      7.0724   37739.0
# 20 1994-09-07    6.3759     6.3759     6.3759      6.3759  156803.0
# 21 1994-09-08    6.9841     6.9841     6.9841      6.9841   86789.0
# 22 1994-09-12    7.6610     7.6610     7.6610      7.6610  108685.0
# 23 1994-09-13    6.9056     6.9056     6.9056      6.9056  163573.0
# 24 1994-09-14    7.0233     7.0233     7.0233      7.0233   67828.0
# 25 1994-09-15    6.8860     6.8860     6.8860      6.8860   39334.0
# 26 1994-09-19    6.8664     6.8664     6.8664      6.8664   54914.0
# 27 1994-09-20    6.1895     6.1895     6.1895      6.1895   63258.0
# 28 1994-09-21    5.6304     5.6304     5.6304      5.6304   89661.0
# 29 1994-09-22    5.8560     5.8560     5.8560      5.8560   79343.0
# 30 1994-09-26    5.6991     5.6991     5.6991      5.6991   49891.0
# 31 1994-09-27    5.2872     5.2872     5.2872      5.2872   56520.0
# 32 1994-09-28    5.2872     5.2872     5.2872      5.2872  101838.0
# 33 1994-09-29    5.5912     5.5912     5.5912      5.5912   51087.0
# 34 1994-10-03    6.1503     6.1503     6.1503      6.1503  104549.0
# 35 1994-10-04    6.2092     6.2092     6.2092      6.2092  123799.0
# 36 1994-10-05    6.8272     6.8272     6.8272      6.8272   80134.0
# 37 1994-10-06    6.7193     6.7193     6.7193      6.7193   99861.0
# 38 1994-10-07    6.8468     6.8468     6.8468      6.8468   82013.0
# 39 1994-10-10    6.7193     6.7193     6.7193      6.7193   52166.0
# 40 1994-10-11    6.4152     6.4152     6.4152      6.4152   54413.0
# 41 1994-10-12    6.4152     6.4152     6.4152      6.4152   48188.0
# 42 1994-10-13    5.7776     5.7776     5.7776      5.7776   87821.0
# 43 1994-10-14    6.3269     6.3269     6.3269      6.3269  126534.0
# 44 1994-10-17    6.6212     6.6212     6.6212      6.6212   91002.0
# 45 1994-10-18    6.8272     6.8272     6.8272      6.8272   89757.0
# 46 1994-10-19    6.7193     6.7193     6.7193      6.7193   44166.0
# 47 1994-10-20    6.6016     6.6016     6.6016      6.6016  117705.0
# 48 1994-10-21    6.2681     6.2681     6.2681      6.2681   59848.0
# 49 1994-10-24    5.7972     5.7972     5.7972      5.7972   59138.0
# 50 1994-10-25    5.8756     5.8756     5.8756      5.8756   45691.0
# 51 1994-10-26    5.9051     5.9051     5.9051      5.9051  113586.0
# 52 1994-10-27    5.5912     5.5912     5.5912      5.5912   31924.0
# 53 1994-10-28    5.4735     5.4735     5.4735      5.4735   27974.0
# 54 1994-11-02    6.0228     6.0228     6.0228      6.0228   41354.0
# 55 1994-11-03    5.9639     5.9639     5.9639      5.9639   17056.0
# 56 1994-11-04    5.9443     5.9443     5.9443      5.9443   44719.0
# 57 1994-11-07    5.9051     5.9051     5.9051      5.9051   35038.0
# 58 1994-11-08    5.9051     5.9051     5.9051      5.9051   20199.0
# 59 1994-11-09    5.9247     5.9247     5.9247      5.9247   52356.0
#
#     MovingAverage10  MovingAverage30  MovingAverage60         RSI       ROC  \
# 0               NaN              NaN              NaN         NaN       NaN
# 1               NaN              NaN              NaN  100.000000  0.098346
# 2               NaN              NaN              NaN  100.000000  0.099185
# 3               NaN              NaN              NaN   58.720489 -0.090235
# 4               NaN              NaN              NaN   78.464461  0.180236
# 5               NaN              NaN              NaN   64.461619 -0.056746
# 6               NaN              NaN              NaN   60.032382 -0.020350
# 7               NaN              NaN              NaN   68.085874  0.062418
# 8               NaN              NaN              NaN   73.634941  0.050209
# 9           9.87891              NaN              NaN   50.940256 -0.100226
# 10         10.08402              NaN              NaN   56.470159  0.037565
# 11         10.12521              NaN              NaN   43.308796 -0.079864
# 12         10.05561              NaN              NaN   40.432857 -0.021673
# 13          9.98205              NaN              NaN   29.492739 -0.101247
# 14          9.81423              NaN              NaN   43.348368  0.083314
# 15          9.70339              NaN              NaN   42.770043 -0.004330
# 16          9.56018              NaN              NaN   35.047646 -0.058760
# 17          9.33447              NaN              NaN   32.277517 -0.024278
# 18          9.01466              NaN              NaN   27.051078 -0.049765
# 19          8.72630              NaN              NaN   19.578979 -0.100993
# 20          8.33089              NaN              NaN   15.107683 -0.098481
# 21          8.07880              NaN              NaN   31.744075  0.095390
# 22          7.91500              NaN              NaN   46.109833  0.096920
# 23          7.76981              NaN              NaN   35.825372 -0.098603
# 24          7.56676              NaN              NaN   38.440152  0.017044
# 25          7.35390              NaN              NaN   36.329689 -0.019549
# 26          7.19205              NaN              NaN   35.984982 -0.002846
# 27          6.98311              NaN              NaN   25.694313 -0.098581
# 28          6.75946              NaN              NaN   19.938261 -0.090330
# 29          6.63782         8.414343              NaN   27.903547  0.040068
# 30          6.57014         8.328350              NaN   25.727779 -0.026793
# 31          6.40045         8.201487              NaN   20.579073 -0.072275
# 32          6.16307         8.044560              NaN   20.579073  0.000000
# 33          6.03163         7.927830              NaN   34.934841  0.057497
# 34          5.94433         7.775107              NaN   53.733419  0.099996
# 35          5.87665         7.644647              NaN   55.392842  0.009577
# 36          5.87273         7.541653              NaN   69.446158  0.099530
# 37          5.92571         7.414430              NaN   65.071461 -0.015804
# 38          6.04735         7.273823              NaN   67.984209  0.018975
# 39          6.13368         7.165933              NaN   61.695965 -0.018622
# 40          6.20529         7.035440              NaN   48.593430 -0.045258
# 41          6.31809         6.932447              NaN   48.593430  0.000000
# 42          6.36713         6.815067              NaN   29.182313 -0.099389
# 43          6.44070         6.747380              NaN   50.149968  0.095074
# 44          6.48779         6.666293              NaN   58.245451  0.046516
# 45          6.54959         6.593380              NaN   63.338880  0.031112
# 46          6.53880         6.534527              NaN   58.750862 -0.015804
# 47          6.52703         6.478617              NaN   53.576746 -0.017517
# 48          6.46916         6.425323              NaN   41.055162 -0.050518
# 49          6.37695         6.382817              NaN   29.255424 -0.075126
# 50          6.32299         6.366140              NaN   33.164289  0.013524
# 51          6.27198         6.330173              NaN   34.820534  0.005021
# 52          6.25334         6.261180              NaN   26.333677 -0.053157
# 53          6.16800         6.213443              NaN   23.687790 -0.021051
# 54          6.10816         6.180093              NaN   51.489800  0.100356
# 55          6.02183         6.149357              NaN   49.143394 -0.009780
# 56          5.94433         6.118620              NaN   48.249137 -0.003286
# 57          5.87468         6.109140              NaN   46.194352 -0.006595
# 58          5.83838         6.118297              NaN   46.194352  0.000000
# 59          5.85113         6.120587         7.267465   47.853082  0.003319
#
#            K         D      MACD  MACD_Signal  MACD_Histogram       PPO  \
# 0        NaN       NaN  0.000000     0.000000        0.000000  0.000000
# 1        NaN       NaN  0.008603     0.004528        0.004075  0.000990
# 2        NaN       NaN  0.024179     0.011779        0.012400  0.002644
# 3        NaN       NaN  0.016555     0.013168        0.003387  0.001813
# 4        NaN       NaN  0.041283     0.020033        0.021250  0.004357
# 5        NaN       NaN  0.045210     0.025407        0.019803  0.004712
# 6        NaN       NaN  0.043501     0.028875        0.014626  0.004510
# 7        NaN       NaN  0.054725     0.033414        0.021312  0.005600
# 8        NaN       NaN  0.073959     0.040033        0.033927  0.007442
# 9        NaN       NaN  0.064020     0.043715        0.020304  0.006440
# 10       NaN       NaN  0.064332     0.046720        0.017612  0.006444
# 11       NaN       NaN  0.045365     0.046531       -0.001166  0.004567
# 12       NaN       NaN  0.025091     0.043656       -0.018566  0.002541
# 13  0.028211       NaN -0.014013     0.036179       -0.050192 -0.001439
# 14  0.257175       NaN -0.029112     0.027957       -0.057069 -0.003008
# 15  0.242696       NaN -0.042477     0.019312       -0.061788 -0.004414
# 16  0.047054  0.143784 -0.066838     0.008972       -0.075810 -0.007010
# 17  0.000000  0.136731 -0.092335    -0.002948       -0.089388 -0.009781
# 18  0.000000  0.072438 -0.124272    -0.016975       -0.107298 -0.013324
# 19  0.000000  0.011764 -0.171961    -0.034619       -0.137342 -0.018754
# 20  0.000000  0.000000 -0.230713    -0.056637       -0.174076 -0.025692
# 21  0.129705  0.032426 -0.263632    -0.079598       -0.184034 -0.029792
# 22  0.325004  0.113677 -0.272314    -0.100744       -0.171571 -0.031039
# 23  0.133962  0.147168 -0.299982    -0.122395       -0.177588 -0.034652
# 24  0.206897  0.198892 -0.319544    -0.143634       -0.175910 -0.037339
# 25  0.174507  0.210092 -0.339357    -0.164559       -0.174799 -0.040118
# 26  0.183166  0.174633 -0.356007    -0.184885       -0.171122 -0.042551
# 27  0.000000  0.141142 -0.389168    -0.206442       -0.182726 -0.047212
# 28  0.000000  0.089418 -0.433371    -0.230256       -0.203114 -0.053518
# 29  0.079033  0.065550 -0.463814    -0.254646       -0.209168 -0.058158
# 30  0.025939  0.026243 -0.493699    -0.279500       -0.214199 -0.062869
# 31  0.000000  0.026243 -0.530881    -0.305532       -0.225349 -0.068791
# 32  0.000000  0.026243 -0.561808    -0.331976       -0.229832 -0.074010
# 33  0.128065  0.038501 -0.577744    -0.357256       -0.220488 -0.077151
# 34  0.363594  0.122915 -0.572415    -0.379325       -0.193091 -0.077136
# 35  0.388407  0.220016 -0.564109    -0.398229       -0.165880 -0.076640
# 36  0.887046  0.441778 -0.535361    -0.412226       -0.123136 -0.072995
# 37  0.824895  0.615985 -0.511888    -0.422377       -0.089511 -0.070080
# 38  0.975482  0.768957 -0.485521    -0.428797       -0.056724 -0.066671
# 39  0.906852  0.898568 -0.464968    -0.432469       -0.032499 -0.064084
# 40  0.723262  0.857623 -0.455433    -0.434796       -0.020637 -0.063114
# 41  0.723262  0.832214 -0.445651    -0.435895       -0.009757 -0.062079
# 42  0.314440  0.666954 -0.456928    -0.438021       -0.018907 -0.064229
# 43  0.666645  0.606902 -0.447110    -0.438939       -0.008171 -0.063168
# 44  0.855348  0.639924 -0.427171    -0.437752        0.010580 -0.060528
# 45  0.987433  0.705966 -0.401278    -0.434075        0.032798 -0.056943
# 46  0.898455  0.851970 -0.380867    -0.428717        0.047850 -0.054159
# 47  0.770670  0.877976 -0.365720    -0.422377        0.056657 -0.052146
# 48  0.458754  0.778828 -0.362748    -0.416379        0.053632 -0.051965
# 49  0.018331  0.536553 -0.375392    -0.412259        0.036867 -0.054178
# 50  0.091657  0.334853 -0.382759    -0.409296        0.026537 -0.055607
# 51  0.119248  0.171998 -0.387132    -0.407070        0.019938 -0.056589
# 52  0.000000  0.057309 -0.400931    -0.406454        0.005523 -0.059068
# 53  0.000000  0.052726 -0.416156    -0.407427       -0.008729 -0.061821
# 54  0.405777  0.131256 -0.408928    -0.407578       -0.001350 -0.061020
# 55  0.362266  0.192011 -0.403430    -0.407162        0.003732 -0.060480
# 56  0.347788  0.278958 -0.398083    -0.406252        0.008169 -0.059952
# 57  0.318830  0.358665 -0.393593    -0.404983        0.011390 -0.059550
# 58  0.318830  0.336928 -0.388469    -0.403328        0.014859 -0.059036
# 59  0.362177  0.336906 -0.382086    -0.401200        0.019114 -0.058306
#
#         TEMA        CCI  Percent_Range
# 0   8.278900        NaN            NaN
# 1   8.395918        NaN            NaN
# 2   8.524944        NaN            NaN
# 3   8.622388        NaN            NaN
# 4   8.718852        NaN            NaN
# 5   8.810142        NaN            NaN
# 6   8.893861        NaN            NaN
# 7   8.973045        NaN            NaN
# 8   9.050833        NaN            NaN
# 9   9.124494        NaN            NaN
# 10  9.194054        NaN            NaN
# 11  9.257700        NaN            NaN
# 12  9.314429        NaN            NaN
# 13  9.362322        NaN       0.971789
# 14  9.402015        NaN       0.742825
# 15  9.434213        NaN       0.757304
# 16  9.458903        NaN       0.952946
# 17  9.476134        NaN       1.000000
# 18  9.485727        NaN       1.000000
# 19  9.486922        NaN       1.000000
# 20  9.478766        NaN       1.000000
# 21  9.461690        NaN       0.870295
# 22  9.437054        NaN       0.674996
# 23  9.405281        NaN       0.866038
# 24  9.367052        NaN       0.793103
# 25  9.322951        NaN       0.825493
# 26  9.273593        NaN       0.816834
# 27  9.218990        NaN       1.000000
# 28  9.158845        NaN       1.000000
# 29  9.093375        NaN       0.920967
# 30  9.022805        NaN       0.974061
# 31  8.947148        NaN       1.000000
# 32  8.866620        NaN       1.000000
# 33  8.781838        NaN       0.871935
# 34  8.693905        NaN       0.636406
# 35  8.603829        NaN       0.611593
# 36  8.512984        NaN       0.112954
# 37  8.422383        NaN       0.175105
# 38  8.332941   1.962437       0.024518
# 39  8.245271   1.575458       0.093148
# 40  8.159607   0.144138       0.276738
# 41  8.076143   0.319197       0.276738
# 42  7.994531  -2.885558       0.685560
# 43  7.914963   0.585962       0.333355
# 44  7.837826   2.786720       0.144652
# 45  7.763570   4.460581       0.012567
# 46  7.692434   3.944298       0.101545
# 47  7.624483   3.173424       0.229330
# 48  7.559485   0.097100       0.541246
# 49  7.496883  -5.027013       0.981669
# 50  7.436314  -4.802179       0.908343
# 51  7.377529  -5.635679       0.880752
# 52  7.320101 -11.702201       1.000000
# 53  7.263637 -14.361051       1.000000
# 54  7.208280  -4.968953       0.594223
# 55  7.154110  -5.878142       0.637734
# 56  7.101185  -5.427981       0.652212
# 57  7.049529  -5.377678       0.681170
# 58  6.999170  -4.644881       0.681170
# 59  6.950150  -3.609586       0.637823

# %% [markdown]
# **Preprocess new data**

# %%
# drop first 60 rows so all columns have not null data
ta_training_set = daily_data.drop(columns=['Data'])[59:]
ta_dataset, X_ta_scaler, Y_ta_scaler = scale_data(ta_training_set)

# %%
#check dataset for nulls
np.argwhere(np.isnan(ta_dataset))
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
print('dataset shape: ' + str(ta_dataset.shape))
validation_set_size = 60
# using data from last 30 days for validation, rest for training
training_data = ta_dataset[:-validation_set_size,:]

x_train = []
y_train = []
x_valid = []
y_valid = []

# predicting prices from data from last 60 days
for i in range(60, training_data.shape[0]):
  x_train.append(training_data[i-60:i, :])
  y_train.append(training_data[i,:5])

x_train, y_train = np.array(x_train), np.array(y_train)

print('x_train shape: ' + str(x_train.shape))
print('y_train shape: ' + str(y_train.shape))

for i in range(ta_dataset.shape[0] - validation_set_size, ta_dataset.shape[0]):
  x_valid.append(ta_dataset[i-60:i, :])
  y_valid.append(ta_dataset[i,:5])

x_valid, y_valid = np.array(x_valid), np.array(y_valid)

print('x_valid shape: ' + str(x_valid.shape))
print('y_valid shape: ' + str(y_valid.shape))
# Out:
# dataset shape: (6438, 19)
# x_train shape: (6318, 60, 19)
# y_train shape: (6318, 5)
# x_valid shape: (60, 60, 19)
# y_valid shape: (60, 5)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=[x_train.shape[1], x_train.shape[2]]))#, return_sequences=True))

#model.add(Dropout(0.3))
model.add(Dense(100))
model.add(Dense(y_train.shape[1]))

model.summary()

model.compile(loss='mse', optimizer='adam')

history = model.fit(x_train, y_train, epochs=20, validation_data=(x_valid, y_valid))

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                21504
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               6500
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 28,509
# Trainable params: 28,509
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 198/198 [==============================] - 2s 6ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 2/20
# 198/198 [==============================] - 1s 4ms/step - loss: 4.0499e-04 - val_loss: 0.0025
# Epoch 3/20
# 198/198 [==============================] - 1s 4ms/step - loss: 4.2908e-04 - val_loss: 0.0019
# Epoch 4/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.5186e-04 - val_loss: 9.0228e-04
# Epoch 5/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.6968e-04 - val_loss: 5.3859e-04
# Epoch 6/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.3709e-04 - val_loss: 0.0016
# Epoch 7/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.0899e-04 - val_loss: 5.4239e-04
# Epoch 8/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.9074e-04 - val_loss: 9.0859e-04
# Epoch 9/20
# 198/198 [==============================] - 1s 4ms/step - loss: 2.9895e-04 - val_loss: 9.5710e-04
# Epoch 10/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.6141e-04 - val_loss: 7.2849e-04
# Epoch 11/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.0867e-04 - val_loss: 0.0014
# Epoch 12/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.5691e-04 - val_loss: 8.4008e-04
# Epoch 13/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.9671e-04 - val_loss: 5.8304e-04
# Epoch 14/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.1354e-04 - val_loss: 3.9102e-04
# Epoch 15/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.6402e-04 - val_loss: 4.7275e-04
# Epoch 16/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.1654e-04 - val_loss: 4.7399e-04
# Epoch 17/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.8037e-04 - val_loss: 3.8687e-04
# Epoch 18/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.4916e-04 - val_loss: 5.9155e-04
# Epoch 19/20
# 198/198 [==============================] - 1s 4ms/step - loss: 3.4036e-04 - val_loss: 5.0480e-04
# Epoch 20/20
# 198/198 [==============================] - 1s 4ms/step - loss: 2.9025e-04 - val_loss: 4.3577e-04

# %%
# Evaluation of the results is made on closing prices - it gives the most information about the usefullness of the model.  Made on the last 30 days of the stock data

predictions = model.predict(x_valid)
predictions = Y_ta_scaler.inverse_transform(predictions)

mae = np.mean(np.abs((predictions[:,1] - Y_ta_scaler.inverse_transform(y_valid)[:,1])))
naive_forcast_difference = [abs(Y_ta_scaler.inverse_transform(y_valid)[i + 1,1] - Y_ta_scaler.inverse_transform(y_valid)[i,1]) for i in range(y_valid.shape[0] - 1)]
naive_forcast_mae = sum(naive_forcast_difference) / len(naive_forcast_difference)
mape = np.mean((np.abs((predictions[:,1] - Y_ta_scaler.inverse_transform(y_valid)[:,1]))/Y_ta_scaler.inverse_transform(y_valid)[:,1])*100)
naive_forcast_mape = (naive_forcast_mae/Y_ta_scaler.inverse_transform(y_valid)[:,1].mean()) * 100

print('Prediction mean absolute error: ' + str(mae))
print('Naive forcast mean absolute error: ' + str(naive_forcast_mae))

print('Prediction mean absolute percentage error: ' + str(mape))
print('Naive forcast mean absolute percentage error: ' + str(naive_forcast_mape))
# Out:
# Prediction mean absolute error: 6.27066853841146
# Naive forcast mean absolute error: 6.423728813559322
# Prediction mean absolute percentage error: 1.515699803603264
# Naive forcast mean absolute percentage error: 1.5405364318574801

# %%
# Comparision of the closing stock prices
inversed_dataset = Y_ta_scaler.inverse_transform(dataset)
print('Ceny zamknięcia: Przewidywana/Rzeczywista/Różnica')
closing_prices = daily_data['Zamkniecie']
for i in range(predictions.shape[0]):
  print(str(round(predictions[i, 1], 1)) + ' / ' + str(daily_data['Zamkniecie'].iloc[-validation_set_size + i]) + ' / ' + str(round(predictions[i, 1] - daily_data['Zamkniecie'].iloc[-validation_set_size + i], 1)))
# Out:
# Ceny zamknięcia: Przewidywana/Rzeczywista/Różnica
# 383.0 / 353.9 / 29.1
# 373.9 / 365.0 / 8.9
# 380.2 / 368.3 / 11.9
# 380.2 / 371.0 / 9.2
# 381.4 / 393.1 / -11.7
# 399.8 / 381.0 / 18.8
# 394.5 / 383.0 / 11.5
# 394.4 / 387.5 / 6.9
# 398.1 / 388.0 / 10.1
# 399.0 / 399.2 / -0.2
# 410.0 / 395.2 / 14.8
# 407.7 / 401.0 / 6.7
# 413.2 / 398.5 / 14.7
# 411.1 / 402.0 / 9.1
# 412.9 / 417.0 / -4.1
# 424.2 / 417.5 / 6.7
# 428.9 / 410.0 / 18.9
# 421.3 / 412.5 / 8.8
# 423.5 / 427.0 / -3.5
# 434.7 / 425.4 / 9.3
# 436.2 / 416.6 / 19.6
# 427.3 / 418.0 / 9.3
# 427.7 / 410.7 / 17.0
# 420.5 / 410.7 / 9.8
# 418.9 / 408.0 / 10.9
# 416.3 / 406.3 / 10.0
# 411.5 / 415.0 / -3.5
# 423.5 / 408.6 / 14.9
# 415.5 / 409.2 / 6.3
# 418.0 / 414.6 / 3.4
# 426.8 / 408.0 / 18.8
# 417.5 / 437.0 / -19.5
# 449.6 / 460.8 / -11.2
# 461.7 / 446.0 / 15.7
# 453.9 / 438.5 / 15.4
# 448.2 / 440.7 / 7.5
# 450.6 / 439.9 / 10.7
# 451.3 / 430.6 / 20.7
# 444.4 / 428.0 / 16.4
# 439.7 / 436.6 / 3.1
# 446.0 / 433.4 / 12.6
# 445.0 / 432.0 / 13.0
# 442.2 / 429.0 / 13.2
# 438.5 / 430.2 / 8.3
# 439.3 / 417.3 / 22.0
# 427.3 / 403.0 / 24.3
# 416.3 / 405.3 / 11.0
# 415.1 / 404.0 / 11.1
# 412.5 / 402.1 / 10.4
# 411.5 / 385.3 / 26.2
# 401.6 / 400.9 / 0.7
# 413.3 / 407.0 / 6.3
# 418.0 / 402.6 / 15.4
# 414.0 / 410.0 / 4.0
# 419.3 / 429.6 / -10.3
# 438.8 / 431.4 / 7.4
# 443.0 / 418.4 / 24.6
# 430.9 / 382.6 / 48.3
# 404.7 / 397.2 / 7.5
# 410.9 / 398.7 / 12.2

# %%
closing_prices = Y_ta_scaler.inverse_transform(dataset)[-validation_set_size:,1]

predicted_closing_prices = np.round(predictions[:, 1], 1)

plt.figure(figsize=(25,10))
plt.title('Comparision of real and predicted closing prices of CD Projekt', fontsize=24)
plt.xlabel('Date', fontsize=25)
plt.ylabel('Closing price (zł)', fontsize=18)
plt.plot(closing_prices)
plt.plot(predicted_closing_prices)
plt.legend(['Real price',  'Predicted price'], loc='lower right')
plt.show()
