# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# 2.4.0
# 2.4.3

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
import time

pd.set_option('display.max_columns', 70)

start = time.time()

# %%
def scale_data(data):
    list_of_features = []
    list_of_outputs = []
    for column in data.columns:
        list_of_features.append(data[column])
        if column in ['Open', 'Close', 'Highest', 'Lowest', 'Volume', 'Otwarcie', 'Najwyzszy', 'Najnizszy', 'Zamkniecie', 'Wolumen']:
            list_of_outputs.append(data[column])
        
    dataset = np.transpose(list_of_features)
    output_dataset = np.transpose(list_of_outputs)
    X_scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = X_scaler.fit_transform(dataset)
    Y_scaler = MinMaxScaler(feature_range=(0,1))
    Y_scaler.fit_transform(output_dataset)

    return scaled_data, X_scaler, Y_scaler

# %%
def prepare_input_and_output(data, number_of_sessions=60):
    # number_of_sessions - number of considered previous sessions as an input
    X = []
    Y = []
    for i in range(number_of_sessions, data.shape[0]):
        X.append(data[i-number_of_sessions:i, :])
        Y.append(data[i, :5])
    return X, Y

# %%
fundamental_data = pd.read_csv('Testing_data/WiG20_full_data.csv')

fundamental_data.head()
# Out:
#   Spółka        Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen  \
# 0    ACP  2005-02-28    16.358     16.854     16.358      16.526  492612.0
# 1    ACP  2005-03-01    16.741     16.741     15.979      16.308  293232.0
# 2    ACP  2005-03-02    16.308     16.414     15.594      15.817  163743.0
# 3    ACP  2005-03-03    15.817     16.035     15.650      15.650  116137.0
# 4    ACP  2005-03-04    15.707     15.923     15.650      15.923   48766.0
#
#   Kwartały  Wartość księgowa  Cena/WK  Zysk  Cena/Zysk  Przychód  \
# 0  2004/Q4              6.55     2.50  0.02     817.90     23.01
# 1  2004/Q4              6.55     2.56  0.02     837.05     23.01
# 2  2004/Q4              6.55     2.49  0.02     815.40     23.01
# 3  2004/Q4              6.55     2.41  0.02     790.85     23.01
# 4  2004/Q4              6.55     2.40  0.02     785.35     23.01
#
#    Cena/Przychód  Zysk operacyjny  Cena/Zysk operacyjny  \
# 0           0.71             1.03                 15.88
# 1           0.73             1.03                 16.25
# 2           0.71             1.03                 15.83
# 3           0.69             1.03                 15.36
# 4           0.68             1.03                 15.25
#
#    Wartość księgowa Grahama  Cena/Wartość księgowa Grahama  \
# 0                     -4.77                          -3.43
# 1                     -4.77                          -3.51
# 2                     -4.77                          -3.42
# 3                     -4.77                          -3.32
# 4                     -4.77                          -3.29
#
#    Wartość przedsiębiorstwa  Wartość przedsiębiorstwa/Przychody  \
# 0                     33.99                                1.48
# 1                     33.99                                1.48
# 2                     33.99                                1.48
# 3                     33.99                                1.48
# 4                     33.99                                1.48
#
#    Wartość przedsiębiorstwa/EBIT  Wartość przedsiębiorstwa/EBITDA   ROE   ROA  \
# 0                          21.97                             33.1  0.32  0.08
# 1                          21.97                             33.1  0.32  0.08
# 2                          21.97                             33.1  0.32  0.08
# 3                          21.97                             33.1  0.32  0.08
# 4                          21.97                             33.1  0.32  0.08
#
#    Marża zysku operacyjnego  Marża zysku netto  Marża zysku ze sprzedaży  \
# 0                      4.46               0.09                      5.43
# 1                      4.46               0.09                      5.43
# 2                      4.46               0.09                      5.43
# 3                      4.46               0.09                      5.43
# 4                      4.46               0.09                      5.43
#
#    Marża zysku brutto  Marża zysku brutto ze sprzedaży  \
# 0               -1.11                            19.58
# 1               -1.11                            19.58
# 2               -1.11                            19.58
# 3               -1.11                            19.58
# 4               -1.11                            19.58
#
#    Rentowność operacyjna aktywów  \
# 0                           4.06
# 1                           4.06
# 2                           4.06
# 3                           4.06
# 4                           4.06
#
#    Udział zysku netto w przepływach operacyjnych  \
# 0                                          -1.68
# 1                                          -1.68
# 2                                          -1.68
# 3                                          -1.68
# 4                                          -1.68
#
#    Wskaźnik źródeł finansowania inwestycji  Zadłużenie ogólne  \
# 0                                   108.82               0.73
# 1                                   108.82               0.73
# 2                                   108.82               0.73
# 3                                   108.82               0.73
# 4                                   108.82               0.73
#
#    Zadłużenie kapitału własnego  Zadłużenie długoterminowe  \
# 0                          2.84                       0.63
# 1                          2.84                       0.63
# 2                          2.84                       0.63
# 3                          2.84                       0.63
# 4                          2.84                       0.63
#
#    Zadłużenie środków trwałych  Pokrycie aktywów trwałych kapitałami stałymi  \
# 0                         0.34                                          0.93
# 1                         0.34                                          0.93
# 2                         0.34                                          0.93
# 3                         0.34                                          0.93
# 4                         0.34                                          0.93
#
#    Trwałość struktury finansowania  Zastosowanie kapitału obcego  \
# 0                             0.42                          1.34
# 1                             0.42                          1.34
# 2                             0.42                          1.34
# 3                             0.42                          1.34
# 4                             0.42                          1.34
#
#    Wskaźnik ogólnej sytuacji finansowej  Zadłużenie netto  \
# 0                                  0.77       292874000.0
# 1                                  0.77       292874000.0
# 2                                  0.77       292874000.0
# 3                                  0.77       292874000.0
# 4                                  0.77       292874000.0
#
#    Zadłużenie netto / EBITDA  Zadłużenie finansowe netto  \
# 0                       9.04                 127506000.0
# 1                       9.04                 127506000.0
# 2                       9.04                 127506000.0
# 3                       9.04                 127506000.0
# 4                       9.04                 127506000.0
#
#    Zadłużenie finansowe netto / EBITDA  I stopień pokrycia  \
# 0                                 3.94                0.57
# 1                                 3.94                0.57
# 2                                 3.94                0.57
# 3                                 3.94                0.57
# 4                                 3.94                0.57
#
#    II stopień pokrycia  Płynność gotówkowa  Płynność szybka  Płynność bieżąca  \
# 0                 0.93                0.16             0.89              0.96
# 1                 0.93                0.16             0.89              0.96
# 2                 0.93                0.16             0.89              0.96
# 3                 0.93                0.16             0.89              0.96
# 4                 0.93                0.16             0.89              0.96
#
#    Płynność podwyższona  Pokrycie zobowiązań należnościami  \
# 0                  0.32                               0.55
# 1                  0.32                               0.55
# 2                  0.32                               0.55
# 3                  0.32                               0.55
# 4                  0.32                               0.55
#
#    Udział kapitału pracującego w aktywach  \
# 0                                   -0.02
# 1                                   -0.02
# 2                                   -0.02
# 3                                   -0.02
# 4                                   -0.02
#
#    Pokrycie kosztów kapitałem obrotowym  Rotacja należności  Cykl należności  \
# 0                                 -0.04                2.89            126.0
# 1                                 -0.04                2.89            126.0
# 2                                 -0.04                2.89            126.0
# 3                                 -0.04                2.89            126.0
# 4                                 -0.04                2.89            126.0
#
#    Cykl zobowiązań  Rotacja zapasów  Cykl zapasów  Rotacja majątku obrotowego  \
# 0            229.0            19.74          18.0                        1.66
# 1            229.0            19.74          18.0                        1.66
# 2            229.0            19.74          18.0                        1.66
# 3            229.0            19.74          18.0                        1.66
# 4            229.0            19.74          18.0                        1.66
#
#    Rotacja majątku trwałego  Rotacja majątku ogółem  Cykl operacyjny  \
# 0                       2.0                    0.91            144.0
# 1                       2.0                    0.91            144.0
# 2                       2.0                    0.91            144.0
# 3                       2.0                    0.91            144.0
# 4                       2.0                    0.91            144.0
#
#    Cykl konwersji gotówki
# 0                   -85.0
# 1                   -85.0
# 2                   -85.0
# 3                   -85.0
# 4                   -85.0

# %%
for column in fundamental_data.columns[8:]:
    scaled_stocks = []
#     print(column)
    data = fundamental_data[['Otwarcie', 'Najwyzszy', 'Najnizszy', 'Zamkniecie', 'Wolumen', column]].dropna()
    
    for stock in list(data['Spółka'].unique()) :
        # Date, stock and quarters is dropped as it isn't considered for learning
        scaled_stock, X_scaler, Y_scaler = scale_data(data)

        scaled_stocks.append(scaled_stock)
        X_scalers.append(X_scaler)
        Y_scalers.append(Y_scaler)
    
    scaled_data, X_scaler, Y_scaler = scale_data(data)
    X, Y = prepare_input_and_output(scaled_data)
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2shuffle=False)
# Out:
# Wartość księgowa
# Cena/WK
# Zysk
# Cena/Zysk
# Przychód
# Cena/Przychód
# Zysk operacyjny
# Cena/Zysk operacyjny
# Wartość księgowa Grahama
# Cena/Wartość księgowa Grahama
# Wartość przedsiębiorstwa
# Wartość przedsiębiorstwa/Przychody
# Wartość przedsiębiorstwa/EBIT
# Wartość przedsiębiorstwa/EBITDA
# ROE
# ROA
# Marża zysku operacyjnego
# Marża zysku netto
# Marża zysku ze sprzedaży
# Marża zysku brutto
# Marża zysku brutto ze sprzedaży
# Rentowność operacyjna aktywów
# Udział zysku netto w przepływach operacyjnych
# Wskaźnik źródeł finansowania inwestycji
# Zadłużenie ogólne
# Zadłużenie kapitału własnego
# Zadłużenie długoterminowe
# Zadłużenie środków trwałych
# Pokrycie aktywów trwałych kapitałami stałymi
# Trwałość struktury finansowania
# Zastosowanie kapitału obcego
# Wskaźnik ogólnej sytuacji finansowej
# Zadłużenie netto
# Zadłużenie netto / EBITDA
# Zadłużenie finansowe netto
# Zadłużenie finansowe netto / EBITDA
# I stopień pokrycia
# II stopień pokrycia
# Płynność gotówkowa
# Płynność szybka
# Płynność bieżąca
# Płynność podwyższona
# Pokrycie zobowiązań należnościami
# Udział kapitału pracującego w aktywach
# Pokrycie kosztów kapitałem obrotowym
# Rotacja należności
# Cykl należności
# Cykl zobowiązań
# Rotacja zapasów
# Cykl zapasów
# Rotacja majątku obrotowego
# Rotacja majątku trwałego
# Rotacja majątku ogółem
# Cykl operacyjny
# Cykl konwersji gotówki

# %%
scaled_stocks = []
X_scalers = []
Y_scalers = []


for stock in list(set(fundamental_data['Spółka'].unique()) - set(['ALR', 'PEO', 'PGN', 'PKO', 'PZU', 'SPL'])) :
    # Date, stock and quarters is dropped as it isn't considered for learning
    scaled_stock, X_scaler, Y_scaler = scale_data(fundamental_data.loc[fundamental_data['Spółka'] == stock].drop(columns=['Spółka', 'Data', 'Kwartały']))
  
    scaled_stocks_fa.append(scaled_stock)
    X_scalers_fa.append(X_scaler)
    Y_scalers_fa.append(Y_scaler)
